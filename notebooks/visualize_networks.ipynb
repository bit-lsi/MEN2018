# %% [markdown]
# # Visualizing our networks

# %%
import os
import pybel
import pybel_jupyter

# %%
pybel_jupyter.get_version()
# Out:
# '0.2.0'

# %%
pybel.get_version()
# Out:
# '0.13.1'

# %%
HERE = os.path.realpath('__file__')
NOTEBOOK_DIRECTORY = os.path.abspath(os.path.join(HERE, os.pardir))
PROJECT_DIRECTORY = os.path.abspath(os.path.join(NOTEBOOK_DIRECTORY, os.pardir))

CURATION = os.path.join(PROJECT_DIRECTORY, 'curation')

# %%
MAOB = os.path.join(CURATION, 'MAOB', 'MAOB.json')
IRS1 = os.path.join(CURATION, 'IRS1', 'IRS1.json')
IGF1R = os.path.join(CURATION, 'IGF1R', 'IGF1R.json')
KETO = os.path.join(CURATION, '7-keto-DHEA', '7KETO.json')
TREM2 = os.path.join(CURATION, 'TREM2', 'TREM2.json')

# %% [markdown]
# # KETO7

# %%
keto_graph = pybel.from_json_path(KETO, check_version=False)
pybel_jupyter.to_jupyter(keto_graph)

# %% [markdown]
# # MAOB

# %%
maob_graph = pybel.from_json_path(MAOB, check_version=False)
pybel_jupyter.to_jupyter(maob_graph)

# %% [markdown]
# # TREM 2

# %%
trem2_graph = pybel.from_json_path(TREM2, check_version=False)
pybel_jupyter.to_jupyter(trem2_graph)

# %% [markdown]
# # IGFR1

# %%
igf1r_graph = pybel.from_json_path(IGF1R, check_version=False)
pybel_jupyter.to_jupyter(igf1r_graph)

# %% [markdown]
# # IRS1

# %%
irs1_graph = pybel.from_json_path(IRS1, check_version=False)
pybel_jupyter.to_jupyter(irs1_graph)
